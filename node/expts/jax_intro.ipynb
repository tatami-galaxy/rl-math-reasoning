# %%
import jax
import numpy as np
import jax.numpy as jnp
from jax import random, jit, grad, jacobian, vmap

# %%
x = jnp.arange(5)
isinstance(x, jax.Array)
# Out:
# W1211 07:38:38.682917  535952 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:38.684403  535950 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:38.685552  535951 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:38.686476  535947 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:38.713651  535953 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:38.731543  535946 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:38.737620  535948 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:38.754984  535949 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:40.899784  535601 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:40.903605  535601 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:40.907051  535601 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:40.910565  535601 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:40.913164  535601 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:40.915812  535601 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:40.918318  535601 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W1211 07:38:40.920831  535601 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# True

# %%
x.devices()
# Out:
# {CudaDevice(id=0)}

# %%
def norm(X):
  X = X - X.mean(0)
  return X / X.std(0)

# %%
norm_compiled = jit(norm)

# %%
np.random.seed(1701)
X = jnp.array(np.random.rand(10000, 10))
np.allclose(norm(X), norm_compiled(X), atol=1E-6)
# Out:
# True

# %%
# %timeit norm(X).block_until_ready()
# %timeit norm_compiled(X).block_until_ready()
# Out:
# 279 μs ± 37.5 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 62.4 μs ± 3.82 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
def sum_logistic(x):
  return jnp.sum(1.0 / (1.0 + jnp.exp(-x)))

# %%
x_small = jnp.arange(3.)
derivative_fn = grad(sum_logistic)
print(derivative_fn(x_small))
# Out:
# [0.25       0.19661194 0.10499357]

# %%
print(grad(jit(grad(jit(grad(sum_logistic)))))(1.0))
# Out:
# -0.0353256

# %%
print(jacobian(jnp.exp)(x_small))
# Out:
# [[1.        0.        0.       ]
#  [0.        2.7182817 0.       ]
#  [0.        0.        7.389056 ]]

# %%
key = random.key(1701)
key1, key2 = random.split(key)
mat = random.normal(key1, (150, 100))
batched_x = random.normal(key2, (10, 100))

def apply_matrix(x):
  return jnp.dot(mat, x)

# %%
def naively_batched_apply_matrix(v_batched):
  return jnp.stack([apply_matrix(v) for v in v_batched])

print('Naively batched')
# %timeit naively_batched_apply_matrix(batched_x).block_until_ready()
# Out:
# Naively batched
# The slowest run took 4.62 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1.65 ms ± 1.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
@jit
def batched_apply_matrix(batched_x):
  return jnp.dot(batched_x, mat.T)

np.testing.assert_allclose(naively_batched_apply_matrix(batched_x), batched_apply_matrix(batched_x), atol=1E-2, rtol=1E-2)
print('Manually batched')
# %timeit batched_apply_matrix(batched_x).block_until_ready()
# Out:
# Manually batched
# The slowest run took 34.22 times longer than the fastest. This could mean that an intermediate result is being cached.
# 895 μs ± 955 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
@jit
def vmap_batched_apply_matrix(batched_x):
  return vmap(apply_matrix)(batched_x)

np.testing.assert_allclose(naively_batched_apply_matrix(batched_x),
                           vmap_batched_apply_matrix(batched_x), atol=1E-2, rtol=1E-2)
print('Auto-vectorized with vmap')
# %timeit vmap_batched_apply_matrix(batched_x).block_until_ready()
# Out:
# Auto-vectorized with vmap
# 114 μs ± 61.9 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
