# %%
import equinox as eqx
import jax
import jax.numpy as jnp
import optax  # https://github.com/deepmind/optax
import torch  # https://pytorch.org
import torchvision  # https://pytorch.org
from jaxtyping import Array, Float, Int, PyTree  # https://github.com/google/jaxtyping

# %%
# Hyperparameters

BATCH_SIZE = 64
LEARNING_RATE = 3e-4
STEPS = 300
PRINT_EVERY = 30
SEED = 42

key = jax.random.PRNGKey(SEED)
# Out:
# E0107 15:33:09.756787 1159166 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.10.2 but source was compiled with: 9.12.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0107 15:33:09.767239 1159166 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.10.2 but source was compiled with: 9.12.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0107 15:33:09.797904 1159166 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.10.2 but source was compiled with: 9.12.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0107 15:33:09.809086 1159166 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.10.2 but source was compiled with: 9.12.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# ---------------------------------------------------------------------------
# JaxRuntimeError                           Traceback (most recent call last)
# Cell In[2], line 9
#       6 PRINT_EVERY = 30
#       7 SEED = 42
# ----> 9 key = jax.random.PRNGKey(SEED)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/random.py:248, in PRNGKey(seed, impl)
#     222 def PRNGKey(seed: int | ArrayLike, *,
#     223             impl: PRNGSpecDesc | None = None) -> Array:
#     224   """Create a legacy PRNG key given an integer seed.
#     225
#     226   This function produces old-style legacy PRNG keys, which are arrays
#    (...)    246     and ``fold_in``.
#     247   """
# --> 248   return _return_prng_keys(True, _key('PRNGKey', seed, impl))
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/random.py:200, in _key(ctor_name, seed, impl_spec)
#     196 if np.ndim(seed):
#     197   raise TypeError(
#     198       f"{ctor_name} accepts a scalar seed, but was given an array of "
#     199       f"shape {np.shape(seed)} != (). Use jax.vmap for batching")
# --> 200 return prng.random_seed(seed, impl=impl)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/prng.py:566, in random_seed(seeds, impl)
#     561 def random_seed(seeds: int | typing.ArrayLike, impl: PRNGImpl) -> PRNGKeyArray:
#     562   # Avoid overflow error in X32 mode by first converting ints to int64.
#     563   # This breaks JIT invariance for large ints, but supports the common
#     564   # use-case of instantiating with Python hashes in X32 mode.
#     565   if isinstance(seeds, int):
# --> 566     seeds_arr = jnp.asarray(np.int64(seeds))
#     567   else:
#     568     seeds_arr = jnp.asarray(seeds)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/numpy/array_constructors.py:401, in asarray(a, dtype, order, copy, device, out_sharding)
#     399 if dtype is not None:
#     400   dtype = dtypes.check_and_canonicalize_user_dtype(dtype, "asarray")
# --> 401 return array(a, dtype=dtype, copy=bool(copy), order=order, device=device,
#     402              out_sharding=out_sharding)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/numpy/array_constructors.py:286, in array(object, dtype, copy, order, ndmin, device, out_sharding)
#     284 else:
#     285   raise TypeError(f"Unexpected input type for array: {type(object)}")
# --> 286 out_array: Array = lax._convert_element_type(
#     287     out, dtype, weak_type=weak_type, sharding=sharding)
#     288 if ndmin > np.ndim(out_array):
#     289   out_array = lax.expand_dims(out_array, range(ndmin - np.ndim(out_array)))
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/lax/lax.py:1689, in _convert_element_type(operand, new_dtype, weak_type, sharding, warn_on_complex_to_real_cast)
#    1687   return operand
#    1688 else:
# -> 1689   return convert_element_type_p.bind(
#    1690       operand, new_dtype=new_dtype, weak_type=bool(weak_type),
#    1691       sharding=sharding)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py:633, in Primitive.bind(self, *args, **params)
#     631 def bind(self, *args, **params):
#     632   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 633   return self._true_bind(*args, **params)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py:649, in Primitive._true_bind(self, *args, **params)
#     647 trace_ctx.set_trace(eval_trace)
#     648 try:
# --> 649   return self.bind_with_trace(prev_trace, args, params)
#     650 finally:
#     651   trace_ctx.set_trace(prev_trace)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/lax/lax.py:4989, in _convert_element_type_bind_with_trace(trace, args, params)
#    4987 def _convert_element_type_bind_with_trace(trace, args, params):
#    4988   sharding = params['sharding']
# -> 4989   operand = core.Primitive.bind_with_trace(convert_element_type_p, trace, args, params)
#    4990   if sharding is not None and sharding._is_concrete:
#    4991     with core.set_current_trace(trace):
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py:661, in Primitive.bind_with_trace(self, trace, args, params)
#     659     with set_current_trace(trace):
#     660       return self.to_lojax(*args, **params)  # type: ignore
# --> 661   return trace.process_primitive(self, args, params)
#     662 trace.process_primitive(self, args, params)  # may raise lojax error
#     663 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py:1210, in EvalTrace.process_primitive(self, primitive, args, params)
#    1208 args = map(full_lower, args)
#    1209 check_eval_args(args)
# -> 1210 return primitive.impl(*args, **params)
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/dispatch.py:91, in apply_primitive(prim, *args, **params)
#      89 prev = config.disable_jit.swap_local(False)
#      90 try:
# ---> 91   outs = fun(*args)
#      92 finally:
#      93   config.disable_jit.set_local(prev)
#
#     [... skipping hidden 11 frame]
#
# File ~/miniconda3/envs/jax/lib/python3.12/site-packages/jax/_src/compiler.py:362, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     353       return backend.compile_and_load(
#     354           module,
#     355           executable_devices=executable_devices,
#     356           compile_options=options,
#     357           host_callbacks=host_callbacks,
#     358       )
#     359     # Some backends don't have `host_callbacks` option yet
#     360     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     361     # to take in `host_callbacks`
# --> 362     return backend.compile_and_load(
#     363         module,
#     364         executable_devices=executable_devices,
#     365         compile_options=options,
#     366     )
#     367 except _jax.JaxRuntimeError as e:
#     368   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# JaxRuntimeError: FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.

# %%
normalise_data = torchvision.transforms.Compose(
    [
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.5,), (0.5,)),
    ]
)
train_dataset = torchvision.datasets.MNIST(
    "MNIST",
    train=True,
    download=True,
    transform=normalise_data,
)
test_dataset = torchvision.datasets.MNIST(
    "MNIST",
    train=False,
    download=True,
    transform=normalise_data,
)
trainloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True
)
testloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=True
)

# %%
# Checking our data a bit (by now, everyone knows what the MNIST dataset looks like)
dummy_x, dummy_y = next(iter(trainloader))
dummy_x = dummy_x.numpy()
dummy_y = dummy_y.numpy()
print(dummy_x.shape)  # 64x1x28x28
print(dummy_y.shape)  # 64
print(dummy_y)
