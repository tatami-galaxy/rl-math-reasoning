# %%
import equinox as eqx
import jax
import jax.numpy as jnp
import optax  # https://github.com/deepmind/optax
import torch  # https://pytorch.org
import torchvision  # https://pytorch.org
from jaxtyping import Array, Float, Int, PyTree  # https://github.com/google/jaxtyping

# %%
# Hyperparameters

BATCH_SIZE = 64
LEARNING_RATE = 3e-4
STEPS = 300
PRINT_EVERY = 30
SEED = 42

key = jax.random.PRNGKey(SEED)
# Out:
# W0107 15:37:01.024047 3459643 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:01.030031 3459644 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:01.038572 3459641 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:01.040309 3459639 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:01.041973 3459640 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:01.044129 3459642 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:01.057457 3459646 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:01.073765 3459645 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:03.519488 3459187 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:03.522722 3459187 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:03.526276 3459187 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:03.529514 3459187 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:03.532749 3459187 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:03.536168 3459187 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:03.539147 3459187 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# W0107 15:37:03.542297 3459187 cuda_executor.cc:1802] GPU interconnect information not available: INTERNAL: NVML doesn't support extracting fabric info or NVLink is not used by the device.
# E0107 15:37:03.581548 3459187 cuda_dnn.cc:456] Loaded runtime CuDNN library: 9.10.2 but source was compiled with: 9.12.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0107 15:37:03.592051 3459187 cuda_dnn.cc:456] Loaded runtime CuDNN library: 9.10.2 but source was compiled with: 9.12.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0107 15:37:03.686351 3459187 cuda_dnn.cc:456] Loaded runtime CuDNN library: 9.10.2 but source was compiled with: 9.12.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0107 15:37:03.703337 3459187 cuda_dnn.cc:456] Loaded runtime CuDNN library: 9.10.2 but source was compiled with: 9.12.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# ---------------------------------------------------------------------------
# JaxRuntimeError                           Traceback (most recent call last)
# Cell In[3], line 9
#       6 PRINT_EVERY = 30
#       7 SEED = 42
# ----> 9 key = jax.random.PRNGKey(SEED)
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/random.py:248, in PRNGKey(seed, impl)
#     222 def PRNGKey(seed: int | ArrayLike, *,
#     223             impl: PRNGSpecDesc | None = None) -> Array:
#     224   """Create a legacy PRNG key given an integer seed.
#     225
#     226   This function produces old-style legacy PRNG keys, which are arrays
#    (...)    246     and ``fold_in``.
#     247   """
# --> 248   return _return_prng_keys(True, _key('PRNGKey', seed, impl))
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/random.py:200, in _key(ctor_name, seed, impl_spec)
#     196 if np.ndim(seed):
#     197   raise TypeError(
#     198       f"{ctor_name} accepts a scalar seed, but was given an array of "
#     199       f"shape {np.shape(seed)} != (). Use jax.vmap for batching")
# --> 200 return prng.random_seed(seed, impl=impl)
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/prng.py:554, in random_seed(seeds, impl)
#     549 def random_seed(seeds: int | typing.ArrayLike, impl: PRNGImpl) -> PRNGKeyArray:
#     550   # Avoid overflow error in X32 mode by first converting ints to int64.
#     551   # This breaks JIT invariance for large ints, but supports the common
#     552   # use-case of instantiating with Python hashes in X32 mode.
#     553   if isinstance(seeds, int):
# --> 554     seeds_arr = jnp.asarray(np.int64(seeds))
#     555   else:
#     556     seeds_arr = jnp.asarray(seeds)
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/numpy/array_constructors.py:401, in asarray(a, dtype, order, copy, device, out_sharding)
#     399 if dtype is not None:
#     400   dtype = dtypes.check_and_canonicalize_user_dtype(dtype, "asarray")
# --> 401 return array(a, dtype=dtype, copy=bool(copy), order=order, device=device,
#     402              out_sharding=out_sharding)
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/numpy/array_constructors.py:286, in array(object, dtype, copy, order, ndmin, device, out_sharding)
#     284 else:
#     285   raise TypeError(f"Unexpected input type for array: {type(object)}")
# --> 286 out_array: Array = lax._convert_element_type(
#     287     out, dtype, weak_type=weak_type, sharding=sharding)
#     288 if ndmin > np.ndim(out_array):
#     289   out_array = lax.expand_dims(out_array, range(ndmin - np.ndim(out_array)))
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/lax/lax.py:1727, in _convert_element_type(operand, new_dtype, weak_type, sharding, warn_on_complex_to_real_cast)
#    1725   return operand
#    1726 else:
# -> 1727   return convert_element_type_p.bind(
#    1728       operand, new_dtype=new_dtype, weak_type=bool(weak_type),
#    1729       sharding=sharding)
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/core.py:632, in Primitive.bind(self, *args, **params)
#     630 def bind(self, *args, **params):
#     631   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 632   return self._true_bind(*args, **params)
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/core.py:648, in Primitive._true_bind(self, *args, **params)
#     646 trace_ctx.set_trace(eval_trace)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, params)
#     649 finally:
#     650   trace_ctx.set_trace(prev_trace)
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/lax/lax.py:5035, in _convert_element_type_bind_with_trace(trace, args, params)
#    5033 def _convert_element_type_bind_with_trace(trace, args, params):
#    5034   sharding = params['sharding']
# -> 5035   operand = core.Primitive.bind_with_trace(convert_element_type_p, trace, args, params)
#    5036   if sharding is not None and sharding._is_concrete:
#    5037     with core.set_current_trace(trace):
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/core.py:660, in Primitive.bind_with_trace(self, trace, args, params)
#     658     with set_current_trace(trace):
#     659       return self.to_lojax(*args, **params)  # type: ignore
# --> 660   return trace.process_primitive(self, args, params)
#     661 trace.process_primitive(self, args, params)  # may raise lojax error
#     662 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/core.py:1189, in EvalTrace.process_primitive(self, primitive, args, params)
#    1187 args = map(full_lower, args)
#    1188 check_eval_args(args)
# -> 1189 return primitive.impl(*args, **params)
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/dispatch.py:92, in apply_primitive(prim, *args, **params)
#      90 prev = config.disable_jit.swap_local(False)
#      91 try:
# ---> 92   outs = fun(*args)
#      93 finally:
#      94   config.disable_jit.set_local(prev)
#
#     [... skipping hidden 11 frame]
#
# File ~/anaconda3/envs/jax/lib/python3.13/site-packages/jax/_src/compiler.py:362, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     353       return backend.compile_and_load(
#     354           module,
#     355           executable_devices=executable_devices,
#     356           compile_options=options,
#     357           host_callbacks=host_callbacks,
#     358       )
#     359     # Some backends don't have `host_callbacks` option yet
#     360     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     361     # to take in `host_callbacks`
# --> 362     return backend.compile_and_load(
#     363         module,
#     364         executable_devices=executable_devices,
#     365         compile_options=options,
#     366     )
#     367 except _jax.JaxRuntimeError as e:
#     368   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# JaxRuntimeError: FAILED_PRECONDITION: DNN library initialization failed. Look at the errors above for more details.

# %%
normalise_data = torchvision.transforms.Compose(
    [
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.5,), (0.5,)),
    ]
)
train_dataset = torchvision.datasets.MNIST(
    "MNIST",
    train=True,
    download=True,
    transform=normalise_data,
)
test_dataset = torchvision.datasets.MNIST(
    "MNIST",
    train=False,
    download=True,
    transform=normalise_data,
)
trainloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True
)
testloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=True
)

# %%
# Checking our data a bit (by now, everyone knows what the MNIST dataset looks like)
dummy_x, dummy_y = next(iter(trainloader))
dummy_x = dummy_x.numpy()
dummy_y = dummy_y.numpy()
print(dummy_x.shape)  # 64x1x28x28
print(dummy_y.shape)  # 64
print(dummy_y)
